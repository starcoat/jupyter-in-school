# %% [markdown]
# # Willkommen!

# %% [markdown]
# Das hier ist ein __Test__.

# %%
# Python-Code:

from datetime import datetime

print("Heute ist der " + datetime.today().strftime('%d.%m.%Y'))
# Out:
# Heute ist der 16.02.2026
