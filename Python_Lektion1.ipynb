# %% [markdown]
# # Python entdecken: Wie Programme funktionieren

# %% [markdown]
# ## 1) Was passiert hier?

# %% [markdown]
# <div class="alert alert-block alert-info">
# 🧪 In diesem Notebook wirst du nicht nur Code lesen, sondern selbst verändern und ausführen.<br />
# 🔎 Du wirst Vermutungen formulieren, ausprobieren, Fehler machen und herausfinden, warum etwas funktioniert – oder nicht.<br />
# ⚙️ Programmieren bedeutet, präzise Anweisungen zu formulieren. Schon kleine Änderungen im Code können große Auswirkungen haben.<br />
# ✍️ Arbeite sorgfältig, teste deine Ideen und halte deine Beobachtungen fest.
# </div>

# %% [markdown]
# Was glaubst du macht dieser Code?
#
# ```python
# name = input("Wie heißt du? ")
# tageszeit = input("Welche Tageszeit ist es bei dir gerade? ")
#
# if tageszeit == "Morgen":
#     print("Einen schönen guten Morgen, " + name + "!")
# elif tageszeit == "Abend":
#     print("Einen schönen guten Abend, " + name + "!")
# else:
#     print("Einen schönen guten Tag, " + name + "!")
# ```

# %% [markdown]
# __📝 Halte deine Vermutungen hier fest: 👇__

# %% [markdown]
# ## 2) Code ausführen im Notebook

# %% [markdown]
# <div class="alert alert-block alert-info">
# Um Python-Code in diesem Notebook auszuführen:
# <ol>
#     <li>Klicke die Zelle, in der sich der Code befindet, mit der Maus einmal an. Du siehst nun eine farbige Markierung am linken Rand neben der Zelle.</li>
#     <li>Du kannst nun entweder
#         <ul>
#             <li>mit der Maus in der oberen Leiste auf <kbd>▶</kbd> klicken, oder</li>
#             <li>auf deiner Tastatur die Taste <kbd>STRG</kbd> halten und dann <kbd>ENTER</kbd> drücken</li>
#         </ul>
#     </li>
# </ol>
# </div>

# %%
print("Hallo Welt!")

# %% [markdown]
# <details>
# <summary>Code zum Wiederherstellen anzeigen</summary>
#
# ```python
# print("Hallo Welt!")
# ```
#
# </details>

# %% [markdown]
# __#️⃣ 1. Ändere den Code, sodass das Programm statt der Welt *dich* (oder jemand anders) begrüßt.__

# %% [markdown]
# __📝 2. Welcher Befehl wird in Python dazu verwendet, Text auf dem Bildschirm auszugeben? 👇__

# %% [markdown]
# __📝 3. Welche Funktion erfüllen deiner Meinung nach die Klammern ```()``` und die Anführungszeichen ```""```? 👇__

# %% [markdown]
# ## 3) Werte speichern und wiederverwenden

# %% [markdown]
# <div class="alert alert-block alert-success">
# Betrachte den folgenden Code genau.<br >
# Bevor du ihn ausführst:
#
# 🔎 Was fällt dir im Vergleich zu <code>print("Hallo Welt!")</code> auf?
# </div>

# %%
name = "Welt"
print("Hallo " + name + "!")

# %% [markdown]
# <details>
# <summary>Code zum Wiederherstellen anzeigen</summary>
#
# ```python
# name = "Welt"
# print("Hallo " + name + "!")
# ```
#
# </details>

# %% [markdown]
# __#️⃣ 1. Führe den Code aus.__

# %% [markdown]
# __#️⃣ 2. Verändere nur das Wort <code>Welt</code>. Was ändert sich?__

# %% [markdown]
# __#️⃣ 3. Verändere nur das Wort <code>name</code>. Was passiert?__

# %% [markdown]
# __#️⃣ 4. Entferne das Pluszeichen <code>+</code>. Was geschieht?__

# %% [markdown]
# __📝 5. Welche Rolle spielt die Zeile <code>name = "Welt"</code>? 👇__

# %% [markdown]
# __📝 6. Warum steht <code>name</code> später ohne Anführungszeichen? 👇__

# %% [markdown]
# <div class="alert alert-block alert-info">
# In Python kann man Werte unter einem Namen speichern.<br />
# Solche „Speicherplätze mit Namen“ nennt man <strong>Variablen</strong>.
# </div>

# %% [markdown]
# __📝 7. Woran erkennt man im Code, dass etwas gespeichert wird? 👇__

# %% [markdown]
# ## 4) Programme reagieren auf ihre Benutzer/innen

# %% [markdown]
# <div class="alert alert-block alert-success">
#     Im nächsten Beispiel verändert sich das Programm auf eine neue Weise.<br />
#     🧐 Lies den Code und überlege: Was könnte hier anders sein als zuvor?
# </div>

# %%
name = input("Wie heißt du? ")
print("Hallo " + name + "!")

# %% [markdown]
# <details>
# <summary>Code zum Wiederherstellen anzeigen</summary>
#
# ```python
# name = input("Wie heißt du? ")
# print("Hallo " + name + "!")
# ```
#
# </details>

# %% [markdown]
# __#️⃣ 1. Führe den Code aus.__

# %% [markdown]
# __#️⃣ 2. Teste verschiedene Eingaben.__

# %% [markdown]
# __#️⃣ 3. Entferne <code>name =</code> und führe erneut aus.__

# %% [markdown]
# __#️⃣ 4. Ändere den Text innerhalb der Klammern.__

# %% [markdown]
# __📝 5. Was passiert genau zwischen Start und Ausgabe? Beschreibe den Ablauf Schritt für Schritt. 👇__

# %% [markdown]
# <div class="alert alert-block alert-info">
# Programme können nicht nur etwas ausgeben, sondern auch Informationen entgegennehmen.
#
# <code>input()</code> ermöglicht genau das: <strong>Eingaben</strong> von Benutzer/innen.
# </div>

# %% [markdown]
# __📝 6. Welche Gemeinsamkeiten/Unterschiede haben <code>print()</code> und <code>input()</code>? 👇__
